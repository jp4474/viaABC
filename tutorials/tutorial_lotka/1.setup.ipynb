# %%
import rootutils
from pathlib import Path

rootutils.setup_root(Path.cwd(), indicator=".project-root", pythonpath=True)

from src.viaABC.systems import LotkaVolterra

# %%
lotka_abc = LotkaVolterra()
# Out:
# INFO:src.viaABC.viaABC:Initializing viaABC class
# WARNING:src.viaABC.viaABC:Model is None. The model must be provided to encode the data and run the algorithm.
# The class can be initialized without a model, but it will not
# be able to run the algorithm.
# INFO:src.viaABC.viaABC:viaABC class initialized with the following parameters:
# INFO:src.viaABC.viaABC:num_parameters: 2
# INFO:src.viaABC.viaABC:Mu: [0 0]
# INFO:src.viaABC.viaABC:Sigma: [10 10]
# INFO:src.viaABC.viaABC:t0: 0
# INFO:src.viaABC.viaABC:tmax: 15
# INFO:src.viaABC.viaABC:time_space: [ 1.1  2.4  3.9  5.6  7.5  9.6 11.9 14.4]
# INFO:src.viaABC.viaABC:pooling_method: no_cls
# INFO:src.viaABC.viaABC:metric: pairwise_cosine

# %%
lotka_abc.generate_training_data([50000, 0, 0], save_dir="./", seed=1004)

# Note that you do not need to generate validation data and test data 
# [50000, 0, 0] is fine but this will generate an error 'zero-size array to reduction operation maximum which has no identity'  which can be ignored
# 50000: # of training samples
# 0: # of validation samples
# 0: # of test samples
# Out:
# INFO:src.viaABC.viaABC:Generating training data for training with seed 1004
# WARNING:src.viaABC.viaABC:train_data.npz exists but shapes mismatch. Regenerating...
# INFO:src.viaABC.viaABC:Generating 6 simulations for train data
# INFO:src.viaABC.viaABC:Successfully saved 6 simulations to ./train_data.npz
# INFO:src.viaABC.viaABC:Generated 6 simulations for train data in 0.11 seconds
# INFO:src.viaABC.viaABC:Skipping val data generation because num_simulations is 0
# INFO:src.viaABC.viaABC:Skipping test data generation because num_simulations is 0
# INFO:src.viaABC.viaABC:Training data generation completed and saved. Total time taken: 0.11 seconds
