# %%
import os
import sys

# pwd
def print_working_directory():
    """Print the current working directory."""
    cwd = os.getcwd()
    print(cwd)

print_working_directory()

def print_root_directory():
    """Print the root directory of the project."""
    root = os.path.dirname("../")
    print(os.listdir(root))

print_root_directory()

# IO
root = os.path.dirname("../")
cwd = os.getcwd()
# src code
src_dir = os.path.dirname(os.path.join(root, os.path.dirname('src/viaABC')))
# data code
data_dir = os.path.join(src_dir, 'data')
#
# Out:
# /home/kangyu/viaABC/notebooks
# ['requirements.txt', 'myenv', 'setup.py', 'src', '.project-root', 'README.md', 'environment.yaml', 'data', '.git', 'build', 'configs', '.gitignore', 'tutorials', 'notebooks', 'LICENSE', 'scripts']

# %%
# import data
import numpy as np
import pandas as pd

print("Data file loading: ", os.listdir(data_dir))
# initial_grid1_cpp.txt
data_file_1 = os.path.join(data_dir, 'initial_grid1_cpp.txt')
data_1 = np.loadtxt(data_file_1)
print("Data from initial_grid1_cpp.txt:")
print(data_1.shape)
# Out:
# Data file loading:  ['.gitkeep', 'initial_grid1_cpp.txt']
# Data from initial_grid1_cpp.txt:
# (1200, 1200)

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[0]
sys.path.insert(0, str(PROJECT_ROOT))
print("Project root added to sys.path:", PROJECT_ROOT)
# Out:
# Project root added to sys.path: /home/kangyu/viaABC

# %%
from src.viaABC.systems import Spatial2D
system = Spatial2D(grid_size=(10, 10), diffusion_rate=0.1, decay_rate=0.01)
print("Spatial2D system created with grid size:", system.grid_size)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.viaABC.systems import Spatial2D
#       2 system = Spatial2D(grid_size=(10, 10), diffusion_rate=0.1, decay_rate=0.01)
#       3 print("Spatial2D system created with grid size:", system.grid_size)
#
# File ~/viaABC/src/viaABC/systems.py:1
# ----> 1 from src.viaABC.viaABC import viaABC
#       2 from scipy.stats import uniform
#       3 import numpy as np
#
# File ~/viaABC/src/viaABC/viaABC.py:27
#      24 from tqdm import tqdm
#      26 from src.viaABC.metrics import *
# ---> 27 from src.utils.viaABC_utils.DensityRatioEstimation import dre_cpp
#      28 from src.utils.viaABC_utils.utils import weighted_var, calculate_densratio_basis_sigma, weighted_sample_quantile
#      29 from src.utils.viaABC_utils.ParticleWeight import particle_weight_cpp
#
# File ~/viaABC/src/utils/__init__.py:1
# ...

# %%
import sys, site, os
print("sys.executable =", sys.executable)
print("sys.prefix     =", sys.prefix)
print("site.getsitepackages =", getattr(site, "getsitepackages", lambda: "NA")())
print("cwd =", os.getcwd())
# Out:
# sys.executable = /usr/bin/python3
# sys.prefix     = /usr
# site.getsitepackages = ['/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/lib/python3.10/dist-packages']
# cwd = /home/kangyu/viaABC/notebooks
