# %%
import numpy as np

# %%
train_data = np.load("/home/jp4474/latent-abc-smc/data/SPATIAL/train_data_reshaped.npz", allow_pickle=True)
val_data = np.load("/home/jp4474/latent-abc-smc/data/SPATIAL/val_data_reshaped.npz", allow_pickle=True)

# %%
train_data_sim = train_data['simulations']
val_data_sim = val_data['simulations']

# %%
train_data_sim_reshaped = train_data_sim.reshape(-1, 3, 28, 28)

# %%
print(train_data_sim_reshaped.shape)
print(train_data_sim.shape)
# Out:
# (500000, 3, 28, 28)
# (500000, 3, 28, 28)

# %%
val_data_sim_reshaped = val_data_sim.reshape(-1, 3, 28, 28)

# %%
print(val_data_sim_reshaped.shape)
print(val_data_sim.shape)
# Out:
# (100000, 3, 28, 28)
# (10000, 10, 3, 28, 28)

# %%
np.savez("/home/jp4474/latent-abc-smc/data/SPATIAL/train_data_reshaped.npz", simulations=train_data_sim_reshaped)
np.savez("/home/jp4474/latent-abc-smc/data/SPATIAL/val_data_reshaped.npz", simulations=val_data_sim_reshaped)
